# %%
# %pip install torch

# %%
import xml.etree.ElementTree as ET

file_path = './a-s.xml'  # Replace this with the actual file path

try:
    # Parse the XML file
    tree = ET.parse(file_path)
    root = tree.getroot()

    # Define the namespace used in the XML file
    namespace = {'graf': 'http://www.xces.org/ns/GrAF/1.0/'}

    # Find the region tags with anchors attribute
    regions = root.findall(".//graf:region[@anchors]", namespaces=namespace)

    if not regions:
        print("No regions found with anchors attribute.")
    else:
        for region in regions:
            anchors_value = region.get("anchors")
            print(f"Region found with anchors attribute: {anchors_value}")

except FileNotFoundError:
    print(f"File '{file_path}' not found.")
except ET.ParseError as e:
    print(f"Error parsing XML: {e}")

# %%
import xml.etree.ElementTree as ET

file_path = './a-s.xml'  # Replace this with the actual file path

tree = ET.parse(file_path)
 oot = tree.getroot()

   efine the namespace used in the XML file
    space = {'graf': 'http://www.xces.org/ns/GrAF/1.0/'}

    #  the region tags with anchors attribute
    reg = root.findall(".//graf:region[@anchors]", namespaces=namespace)

    if noprint(regions)

# %%
with open("a.txt") as file:
    content = file.read()

print(content)
print(content[4:47])

# %%
# %pip install wtpsplit
# Out:
# WARNING: You are using pip version 22.0.4; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python310\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 78.3/78.3 KB 4.3 MB/s eta 0:00:00
# ...
#      -------------------------------------- 120.7/120.7 KB 6.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.4/7.4 MB 12.7 MB/s eta 0:00:00
# ...
#      --------------------------------------- 10.7/10.7 MB 12.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 9.3/9.3 MB 12.6 MB/s eta 0:00:00
# ...
#      --------------------------------------- 15.8/15.8 MB 10.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.9/7.9 MB 10.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.7/5.7 MB 11.1 MB/s eta 0:00:00
# ...

# %%
from wtpsplit import WtP

wtp = WtP("wtp-bert-mini")

# returns ["This is a test", "This is another test."]
wtp.split("This is a test This is another test.")

# # returns an iterator yielding a lists of sentences for every text
# # do this instead of calling wtp.split on every text individually for much better performance
# wtp.split(["This is a test This is another test.", "And some more texts..."])

# # if you're using a model with language adapters, also pass a `lang_code`
# wtp.split("This is a test This is another test.", lang_code="en")

# # depending on your usecase, adaptation to e.g. the Universal Dependencies style may give better results
# # this always requires a language code
# wtp.split("This is a test This is another test.", lang_code="en", style="ud")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\wtpsplit\__init__.py:87, in WtP.__init__(self, model_name_or_model, from_pretrained_kwargs, ort_providers, ort_kwargs, mixtures, hub_prefix)
#      86 try:
# ---> 87     import torch  # noqa
#      88 except ModuleNotFoundError:
#
# ModuleNotFoundError: No module named 'torch'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\ea2525\Downloads\wtp\test1.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/ea2525/Downloads/wtp/test1.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> from wtpsplit import WtP
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ea2525/Downloads/wtp/test1.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> wtp = WtP("wtp-bert-mini")
# ...

# %%
import xml.etree.ElementTree as ET

file_path = './a-s.xml'  # Replace this with the actual file pat
tree = ET.parse(file_path)
root = tree.getroot()

# Define the namespace used in the XML file
namespace = {'graf': 'http://www.xces.org/ns/GrAF/1.0/'}

# Find the region tags with anchors attribute
regions = root.findall(".//graf:region[@anchors]", namespaces=namespace)

for region in regions:
